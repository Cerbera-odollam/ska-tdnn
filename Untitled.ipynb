# %%
#!/usr/bin/python
#-*- coding: utf-8 -*-
import sys
import time
import itertools
import importlib
import torch
import torch.nn as nn
import torch.nn.functional as F
from tuneThreshold import tuneThresholdfromScore
from DatasetLoader import test_dataset_loader
from torch.cuda.amp import autocast, GradScaler
from torch.optim.swa_utils import SWALR, AveragedModel
import random

# %%
        feats_eval = {}
        tstart = time.time()
        with open('./list/ASV_test_list copy.txt') as f:
            lines_eval = f.readlines()

# %%
real_lines_eval = lines_eval[:1428]

# %%
        with open('./list/ASV_test_list copy.txt') as f:
            lines_eval = f.readlines()

# %%
        files = list(itertools.chain(*[x.strip().split() for x in real_lines_eval]))

# %%
        setfiles = list(set(files))

# %%
print(setfiles)
# Out:
# ['LA_0001', 'LA_0002', 'LA_0003', 'LA_0005', 'LA_0007', 'LA_0011', 'LA_0013', 'LA_0015', 'LA_0018', 'LA_0021', 'LA_0023', 'LA_0025', 'LA_0028', 'LA_0030', 'LA_0032', 'LA_0036', 'LA_0038', 'LA_0040', 'LA_0044', 'LA_0046', 'LA_0048', 'LA_E_1002903', 'LA_E_1025393', 'LA_E_1030819', 'LA_E_1039348', 'LA_E_1040380', 'LA_E_1048677', 'LA_E_1061586', 'LA_E_1066455', 'LA_E_1082271', 'LA_E_1086117', 'LA_E_1102017', 'LA_E_1103494', 'LA_E_1106135', 'LA_E_1115388', 'LA_E_1122097', 'LA_E_1125558', 'LA_E_1131212', 'LA_E_1136672', 'LA_E_1137577', 'LA_E_1140411', 'LA_E_1145525', 'LA_E_1152151', 'LA_E_1159112', 'LA_E_1159833', 'LA_E_1167109', 'LA_E_1171007', 'LA_E_1172997', 'LA_E_1198781', 'LA_E_1198906', 'LA_E_1203094', 'LA_E_1214304', 'LA_E_1236391', 'LA_E_1240992', 'LA_E_1244665', 'LA_E_1245139', 'LA_E_1250691', 'LA_E_1251876', 'LA_E_1262130', 'LA_E_1264937', 'LA_E_1266211', 'LA_E_1266270', 'LA_E_1268248', 'LA_E_1275973', 'LA_E_1284209', 'LA_E_1291046', 'LA_E_1298039', 'LA_E_1309520', 'LA_E_1313727', 'LA_E_1314263', 'LA_E_1319523', 'LA_E_1330872', 'LA_E_1332460', 'LA_E_1335207', 'LA_E_1337477', 'LA_E_1341529', 'LA_E_1349899', 'LA_E_1350882', 'LA_E_1398372', 'LA_E_1402365', 'LA_E_1409912', 'LA_E_1419852', 'LA_E_1421210', 'LA_E_1444758', 'LA_E_1458883', 'LA_E_1515635', 'LA_E_1524020', 'LA_E_1528765', 'LA_E_1539637', 'LA_E_1542340', 'LA_E_1549576', 'LA_E_1553888', 'LA_E_1558666', 'LA_E_1571445', 'LA_E_1574894', 'LA_E_1578047', 'LA_E_1580381', 'LA_E_1583855', 'LA_E_1596592', 'LA_E_1615488', 'LA_E_1616681', 'LA_E_1617471', 'LA_E_1624904', 'LA_E_1635576', 'LA_E_1637796', 'LA_E_1645649', 'LA_E_1648826', 'LA_E_1677476', 'LA_E_1682343', 'LA_E_1685623
# %%
test_dataset = test_dataset_loader(setfiles, "/home/cymoon/dataset/ASVSpoof/ASVSpoof2019/LA/ASVspoof2019_LA_eval/wav", eval_frames=0, num_eval=1)

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=10, drop_last=False, sampler=None)

# %%
print(type(test_loader))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>

# %%
ds = test_loader.__len__()

# %%
print(ds)
# Out:
# 1428

# %%
enroll_files = list()
# print(type(enr))
with open('./list/ASV_enroll_lst.txt','r') as f:
    lines_enroll = f.readlines()
# print(type(lines_enroll))
files = [x.strip().split(' ') for x in lines_enroll]
# print(files)
for num in files:
    enroll_files_tmp = num[1].strip().split(',')
    for idx in range(len(enroll_files_tmp)):
            enroll_files_tmp[idx] = enroll_files_tmp[idx] + '.wav'
    enroll_files = enroll_files+ enroll_files_tmp 
# print(enroll_files)
enroll_dataset = test_dataset_loader(enroll_files,"/home/cymoon/dataset/ASVSpoof/ASVSpoof2019/LA/ASVspoof2019_LA_eval/wav", eval_frames=0, num_eval=1)
# if distributed:
#     sampler = torch.utils.data.distributed.DistributedSampler(enroll_dataset, shuffle=False)
# else:
#     sampler = None
enroll_loader = torch.utils.data.DataLoader(enroll_dataset, batch_size=1, shuffle=False, num_workers=10, drop_last=False, sampler=None)
ds = test_loader.__len__()
# gs = self.ngpu
for idx, data in enumerate(enroll_loader):
    print(idx)
    exit()
    inp1 = data[0][0].cuda()
    with torch.no_grad():
        if self.swa and epoch >= self.swa_start:
            ref_feat = self.__swa_model__(inp1).detach().cpu()
        else:
            ref_feat = self.__model__(inp1).detach().cpu()
        feats_eval[data[1][0]] = ref_feat
        telapsed = time.time() - tstart
        if rank == 0:
            sys.stdout.write("\r Reading {:d} of {:d}: {:.2f} Hz, embedding size {:d}".format(idx*gs, ds*gs, idx*gs/telapsed,ref_feat.size()[1]))
            sys.stdout.flush()
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 26
#      24 inp1 = data[0][0].cuda()
#      25 with torch.no_grad():
# ---> 26     if self.swa and epoch >= self.swa_start:
#      27         ref_feat = self.__swa_model__(inp1).detach().cpu()
#      28     else:
#
# NameError: name 'self' is not defined

# %%
enroll_files = list()
enroll_idx = list()
# print(type(enr))
with open('./list/ASV_enroll_lst.txt','r') as f:
    lines_enroll = f.readlines()
# print(type(lines_enroll))
files = [x.strip().split(' ') for x in lines_enroll]
# print(files)
for num in files:
    enroll_idx_tmp = num[0].strip().split(',')
    enroll_files_tmp = num[1].strip().split(',')
#     print(enroll_idx_tmp)
    for idx in range(len(enroll_files_tmp)):
            enroll_files_tmp[idx] = enroll_files_tmp[idx] + '.wav'
    enroll_files = enroll_files+ enroll_files_tmp
#     enroll_idx = enroll_idx + enroll_idx_tmp
# # print(enroll_files)
# print(enroll_idx)
